# %% [markdown]
# # Introduction
#
# ## Commerical Product Review Sentiment Analysis
#
# Customer reviews from Amazon and other customer review sites will be analyzed for customer sentiment.
#
# ### Method Approach

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LogisticRegression, Ridge, Lasso, RidgeCV, LassoCV
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.metrics import r2_score, confusion_matrix, roc_auc_score

import requests
import time
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from bs4 import BeautifulSoup
from nltk.stem.porter import PorterStemmer
import regex as re

# %% [markdown]
# # Gather Data

# %%
amazon_reviews = pd.read_excel('./data/K Mini Reviews.xlsx')
amazon_reviews.head()
# Out:
#        ID  FISCAL_YEAR  FISCAL_PERIOD  FISCAL_PERIOD_NUM_COUNTER  \
# 0  573932         2019              4                        233
# 1  564358         2019              2                        231
# 2  573987         2019              4                        233
# 3  574096         2019              4                        233
# 4  574136         2019              4                        233
#
#    FISCAL_WEEK_NUM_OF_YEAR REVIEW_DATE   BRAND  \
# 0                       14  2019-03-31  Keurig
# 1                        8  2019-02-20  Keurig
# 2                       14  2019-04-01  Keurig
# 3                       14  2019-04-03  Keurig
# 4                       14  2019-04-04  Keurig
#
#                                              PRODUCT  PRODUCT_ID  RATING  ...  \
# 0     Keurig K-Mini Single Serve Coffee Maker, Oasis       39021       1  ...
# 1     Keurig K-Mini Single Serve Coffee Maker, Black       39022       1  ...
# 2     Keurig K-Mini Single Serve Coffee Maker, Black       39022       1  ...
# 3  Keurig K-Mini Single Serve Coffee Maker, Studi...       39023       3  ...
# 4     Keurig K-Mini Single Serve Coffee Maker, Black       39022       4  ...
#
#                    TAG NPS       STATUS REPIED_TO INTERNAL_COMMENTS PERMALINK  \
# 0  Single-Serve Brewer   0  Open Ticket       Yes               NaN       NaN
# 1  Single-Serve Brewer   0  Open Ticket        No               NaN       NaN
# 2  Single-Serve Brewer   0  Open Ticket       Yes               NaN       NaN
# 3  Single-Serve Brewer   0  Open Ticket       Yes               NaN       NaN
# 4  Single-Serve Brewer   0  Open Ticket       Yes               NaN       NaN
#
#   SENTIMENT   ALIAS  NEWLY_LOADED CURRENT_PERIOD
# 0  NEGATIVE  K-Mini             0              0
# 1  NEGATIVE  K-Mini             0              0
# 2  NEGATIVE  K-Mini             0              0
# 3   NEUTRAL  K-Mini             0              0
# 4  POSITIVE  K-Mini             0              0
#
# [5 rows x 36 columns]

# %%
all_reviews = pd.read_excel('./data/K_Mini_Reviews-2019-06-27.xlsx')
all_reviews.head()
# Out:
#        ID  FISCAL_YEAR  FISCAL_PERIOD  FISCAL_PERIOD_NUM_COUNTER  \
# 0  319852         2018              6                        223
# 1  319891         2018              6                        223
# 2  319892         2018              6                        223
# 3  319893         2018              6                        223
# 4  319929         2018              6                        223
#
#    FISCAL_WEEK_NUM_OF_YEAR REVIEW_DATE   BRAND  \
# 0                       25  2018-06-22  Keurig
# 1                       25  2018-06-23  Keurig
# 2                       25  2018-06-23  Keurig
# 3                       25  2018-06-23  Keurig
# 4                       26  2018-06-24  Keurig
#
#                                              PRODUCT  PRODUCT_ID  RATING  ...  \
# 0  Keurig K-Mini Single Serve K-Cup Pod Coffee Maker       31565       4  ...
# 1  Keurig K-Mini Single Serve K-Cup Pod Coffee Maker       31565       5  ...
# 2  Keurig K-Mini Single Serve K-Cup Pod Coffee Maker       31565       5  ...
# 3  Keurig K-Mini Single Serve K-Cup Pod Coffee Maker       31565       5  ...
# 4  Keurig K-Mini Single Serve K-Cup Pod Coffee Maker       31565       5  ...
#
#                     TAG  NPS STATUS REPIED_TO INTERNAL_COMMENTS PERMALINK  \
# 0  Single-Serve Brewers  0.0   None        No               NaN       NaN
# 1  Single-Serve Brewers  0.0   None        No               NaN       NaN
# 2  Single-Serve Brewers  0.0   None        No               NaN       NaN
# 3  Single-Serve Brewers  0.0   None        No               NaN       NaN
# 4  Single-Serve Brewers  0.0   None        No               NaN       NaN
#
#   SENTIMENT   ALIAS  NEWLY_LOADED CURRENT_PERIOD
# 0  POSITIVE  K-Mini             0              0
# 1  POSITIVE  K-Mini             0              0
# 2  POSITIVE  K-Mini             0              0
# 3  POSITIVE  K-Mini             0              0
# 4  POSITIVE  K-Mini             0              0
#
# [5 rows x 36 columns]

# %% [markdown]
# # EDA

# %%
all_reviews.dtypes
# Out:
# ID                                    int64
# FISCAL_YEAR                           int64
# FISCAL_PERIOD                         int64
# FISCAL_PERIOD_NUM_COUNTER             int64
# FISCAL_WEEK_NUM_OF_YEAR               int64
# REVIEW_DATE                  datetime64[ns]
# BRAND                                object
# PRODUCT                              object
# PRODUCT_ID                            int64
# RATING                                int64
# SOURCE                               object
# REVIEWER_NAME                        object
# REVIEW                               object
# TITLE                                object
# SYNDICATED                           object
# INCENTIVE_PROGRAM                    object
# VERIFIED_REVIEW                      object
# PRICE                               float64
# SIZE                                float64
# COLOR                                object
# EDITION                             float64
# STYLE                               float64
# OTHER_ATTRIBUTES                    float64
# MODEL                               float64
# SKU                                  object
# CATEGORY                             object
# TAG                                  object
# NPS                                 float64
# STATUS                               object
# REPIED_TO                            object
# INTERNAL_COMMENTS                    object
# PERMALINK                           float64
# SENTIMENT                            object
# ALIAS                                object
# NEWLY_LOADED                          int64
# CURRENT_PERIOD                        int64
# dtype: object

# %%
amazon_reviews.dtypes
# Out:
# ID                                    int64
# FISCAL_YEAR                           int64
# FISCAL_PERIOD                         int64
# FISCAL_PERIOD_NUM_COUNTER             int64
# FISCAL_WEEK_NUM_OF_YEAR               int64
# REVIEW_DATE                  datetime64[ns]
# BRAND                                object
# PRODUCT                              object
# PRODUCT_ID                            int64
# RATING                                int64
# SOURCE                               object
# REVIEWER_NAME                        object
# REVIEW                               object
# TITLE                                object
# SYNDICATED                           object
# INCENTIVE_PROGRAM                    object
# VERIFIED_REVIEW                      object
# PRICE                               float64
# SIZE                                float64
# COLOR                                object
# EDITION                             float64
# STYLE                               float64
# OTHER_ATTRIBUTES                    float64
# MODEL                               float64
# SKU                                  object
# CATEGORY                             object
# TAG                                  object
# NPS                                   int64
# STATUS                               object
# REPIED_TO                            object
# INTERNAL_COMMENTS                    object
# PERMALINK                           float64
# SENTIMENT                            object
# ALIAS                                object
# NEWLY_LOADED                          int64
# CURRENT_PERIOD                        int64
# dtype: object

# %%
list(amazon_reviews.columns)
# Out:
# ['ID',
#  'FISCAL_YEAR',
#  'FISCAL_PERIOD',
#  'FISCAL_PERIOD_NUM_COUNTER',
#  'FISCAL_WEEK_NUM_OF_YEAR',
#  'REVIEW_DATE',
#  'BRAND',
#  'PRODUCT',
#  'PRODUCT_ID',
#  'RATING',
#  'SOURCE',
#  'REVIEWER_NAME',
#  'REVIEW',
#  'TITLE',
#  'SYNDICATED',
#  'INCENTIVE_PROGRAM',
#  'VERIFIED_REVIEW',
#  'PRICE',
#  'SIZE',
#  'COLOR',
#  'EDITION',
#  'STYLE',
#  'OTHER_ATTRIBUTES',
#  'MODEL',
#  'SKU',
#  'CATEGORY',
#  'TAG',
#  'NPS',
#  'STATUS',
#  'REPIED_TO',
#  'INTERNAL_COMMENTS',
#  'PERMALINK',
#  'SENTIMENT',
#  'ALIAS',
#  'NEWLY_LOADED',
#  'CURRENT_PERIOD']

# %%
amazon_reviews['NPS'] = amazon_reviews.NPS.astype(float)

# %%
amazon_reviews.dtypes
# Out:
# ID                                    int64
# FISCAL_YEAR                           int64
# FISCAL_PERIOD                         int64
# FISCAL_PERIOD_NUM_COUNTER             int64
# FISCAL_WEEK_NUM_OF_YEAR               int64
# REVIEW_DATE                  datetime64[ns]
# BRAND                                object
# PRODUCT                              object
# PRODUCT_ID                            int64
# RATING                                int64
# SOURCE                               object
# REVIEWER_NAME                        object
# REVIEW                               object
# TITLE                                object
# SYNDICATED                           object
# INCENTIVE_PROGRAM                    object
# VERIFIED_REVIEW                      object
# PRICE                               float64
# SIZE                                float64
# COLOR                                object
# EDITION                             float64
# STYLE                               float64
# OTHER_ATTRIBUTES                    float64
# MODEL                               float64
# SKU                                  object
# CATEGORY                             object
# TAG                                  object
# NPS                                 float64
# STATUS                               object
# REPIED_TO                            object
# INTERNAL_COMMENTS                    object
# PERMALINK                           float64
# SENTIMENT                            object
# ALIAS                                object
# NEWLY_LOADED                          int64
# CURRENT_PERIOD                        int64
# dtype: object

# %%
amazon_reviews.shape
# Out:
# (79, 36)

# %%
all_reviews.shape
# Out:
# (1182, 36)

# %%
converged_reviews = amazon_reviews[all_reviews.duplicated()]
converged_reviews
# Out:
# C:\Users\Michelle\Anaconda3\envs\dsi\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [ID, FISCAL_YEAR, FISCAL_PERIOD, FISCAL_PERIOD_NUM_COUNTER, FISCAL_WEEK_NUM_OF_YEAR, REVIEW_DATE, BRAND, PRODUCT, PRODUCT_ID, RATING, SOURCE, REVIEWER_NAME, REVIEW, TITLE, SYNDICATED, INCENTIVE_PROGRAM, VERIFIED_REVIEW, PRICE, SIZE, COLOR, EDITION, STYLE, OTHER_ATTRIBUTES, MODEL, SKU, CATEGORY, TAG, NPS, STATUS, REPIED_TO, INTERNAL_COMMENTS, PERMALINK, SENTIMENT, ALIAS, NEWLY_LOADED, CURRENT_PERIOD]
# Index: []
#
# [0 rows x 36 columns]

# %%
merged_reviews = pd.merge(amazon_reviews, all_reviews)
merged_reviews.shape
# Out:
# (22, 36)

# %% [markdown]
# Notes:
# 1.
